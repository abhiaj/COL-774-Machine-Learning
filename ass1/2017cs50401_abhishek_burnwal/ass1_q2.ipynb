# %%
# %matplotlib notebook
# %matplotlib tk
import numpy as np 
import matplotlib.pyplot as plt 
import plotly
import plotly.graph_objects as go
import time
import math
from mpl_toolkits import mplot3d

tx1 = []
tx2 = []
ty = []
tm = 0

f = open("../ass1_data/data/q2/q2test.csv", "r")

for i in f:
    #print(x.strip())
    ''' a is matrix of m*2 size, where the first column is 1 '''
    i = i.strip()
    data = i.split(",")
    if(data[2]=="Y"):
        continue
    tx1.append(data[0])
    tx2.append(data[1])
    ty.append(data[2])
f.close()

# %%
m = 1000000
x1 = np.random.normal(3,2,1000000)
#plt.hist(x1, 30, density=True)

x2 = np.random.normal(-1,2,1000000)
print(x2.shape)
#plt.hist(x2, 30, density=True)

er = np.random.normal(0,math.sqrt(2),1000000)
#plt.hist(er, 30, density=True)

theta = np.array([3, 1, 2], dtype=float)
print(theta)
theta0 = np.full(1000000, theta[0])
print(theta0.shape)

y = theta0 + np.dot(theta[1], x1) + np.dot(theta[2], x2) + er

# plt.hist(y, 30, density=True)
# plt.show()
# Out:
# (1000000,)
# [3. 1. 2.]
# (1000000,)

# %%
print(x1.shape)
# Out:
# (1000000,)

# %%
x1[0]
# Out:
# 3.8111465461246516

# %%
x0 = np.full(1000000, 1)
data = np.column_stack((x0,x1,x2,er))

# %%
data
# Out:
# array([[ 1.        ,  3.81114655, -4.79756804, -1.08749429],
#        [ 1.        ,  4.57067862, -1.17583314, -1.95125709],
#        [ 1.        ,  3.48323542,  1.49744017, -0.47371112],
#        ...,
#        [ 1.        ,  3.11826155,  0.55593032,  1.77452936],
#        [ 1.        ,  1.59028961, -1.81813519,  1.14365157],
#        [ 1.        ,  4.50208759, -2.6818617 , -0.91073217]])

# %%
np.random.shuffle(data)

# %%
data.shape
# Out:
# (1000000, 4)

# %%
y = theta0 + np.dot(theta[1], x1) + np.dot(theta[2], x2) + er
plt.hist(y, 30, density=True)

y = np.dot(theta[0], data[:,0]) + np.dot(theta[1], data[:,1]) + np.dot(theta[2], data[:,2]) + data[:,3]
# plt.hist(y, 30, density=True)
# plt.show()
print(theta.shape)
print(y.shape)

X = data[:,0:3].T
print(X.shape)
Y = y.reshape(1,m).astype(float)
print(Y.shape)
theta = np.zeros((3,1))
print(theta.shape)
# Out:
# (3,)
# (1000000,)
# (3, 1000000)
# (1, 1000000)
# (3, 1)

# %%
def calc_cost(X, Y, theta, i, r):
    s_i = i*r
    f_i = i*r + r - 1
    cost=np.dot(  theta.T.dot(X[:,s_i:f_i+1]) - Y[:,s_i:f_i+1] , ( theta.T.dot(X[:,s_i:f_i+1]) - Y[:,s_i:f_i+1] ).T )
    return cost[0,0]/(2*r)
def calc_cost_batch(X, Y, theta):
    cost=np.dot(  theta.T.dot(X) - Y , ( theta.T.dot(X) - Y ).T )
    return cost[0,0]/(2*X.shape[1])

# %%
# theta = np.array([0,0,0], dtype=float)
m = 1000000
r = 10000
num_batch = int(m/r)
rate = 0.001
stop = 0.00000000001
temp = np.array(theta)
cost_old = cost_new = -1
array_j=[]
array_theta=np.empty((0,3))
array_theta= np.append(array_theta,theta.T,axis=0)
theta_old=theta
error = 1
num_epoch = 0
num = 0
print(theta)
while(1):
    av_gd = 0
    for i in range(0, num_batch):
        
        
        s_i = i*r
        f_i = i*r + r - 1
        gd = rate * np.matmul(np.subtract(Y[:,s_i:f_i+1], np.matmul(theta.T, X[:,s_i:f_i+1])), X[:,s_i:f_i+1].T)
#         for j in range (0, r):
#             index = i*r+j
#             hx = np.dot(theta,data[index,0:3])
#             print(hx)
#             for k in range (0, theta.shape[0]):
#                 temp[k]+= rate*( y[index] - hx )*data[index,k]
        gd = gd/r
#         print(gd)
#             print(temp)
        theta_old = theta
        theta = np.add(theta, gd.T)
        
#         theta = theta + temp
        
        cost_old=cost_new
        cost_new = calc_cost(X,Y,theta,i,r)
        diff=abs(cost_new-cost_old)
        error=np.max(np.abs(theta - theta_old))
        errorp = error/np.max(theta)*100
        array_j.append(cost_new)
        array_theta= np.append(array_theta,theta.T,axis=0)
        av_gd += gd
#         print(len(array_theta))
#         print(cost_old,cost_new)
#         print(theta, np.max(gd))
    num_epoch += 1
    av_gd /= r
    av_gd = np.max(av_gd)
    print("num_epoch:",num_epoch)
    if(av_gd<stop):
        break
    
        #print(theta)

print("theta parameters:",theta)
print("rate:",rate," stopping condition:",stop)
print("Number of epochs:",num_epoch)
# plt.plot(range(0,len(array_j)),array_j)
# plt.show()
# print(theta)
# print(cost_new)
# Out:
# [[0.]
#  [0.]
#  [0.]]
# num_epoch: 1
# num_epoch: 2
# num_epoch: 3
# num_epoch: 4
# num_epoch: 5
# num_epoch: 6
# num_epoch: 7
# num_epoch: 8
# num_epoch: 9
# num_epoch: 10
# num_epoch: 11
# num_epoch: 12
# num_epoch: 13
# num_epoch: 14
# num_epoch: 15
# num_epoch: 16
# num_epoch: 17
# num_epoch: 18
# num_epoch: 19
# num_epoch: 20
# num_epoch: 21
# num_epoch: 22
# num_epoch: 23
# num_epoch: 24
# num_epoch: 25
# num_epoch: 26
# num_epoch: 27
# num_epoch: 28
# num_epoch: 29
# num_epoch: 30
# num_epoch: 31
# num_epoch: 32
# num_epoch: 33
# num_epoch: 34
# num_epoch: 35
# num_epoch: 36
# num_epoch: 37
# num_epoch: 38
# num_epoch: 39
# num_epoch: 40
# num_epoch: 41
# num_epoch: 42
# num_epoch: 43
# num_epoch: 44
# num_epoch: 45
# num_epoch: 46
# num_epoch: 47
# num_epoch: 48
# num_epoch: 49
# num_epoch: 50
# num_epoch: 51
# num_epoch: 52
# num_epoch: 53
# num_epoch: 54
# num_epoch: 55
# num_epoch: 56
# num_epoch: 57
# num_epoch: 58
# num_epoch: 59
# num_epoch: 60
# num_epoch: 61
# num_epoch: 62
# num_epoch: 63
# num_epoch: 64
# num_epoch: 65
# num_epoch: 66
# num_epoch: 67
# num_epoch: 68
# num_epoch: 69
# num_epoch: 70
# num_epoch: 71
# num_epoch: 369
# num_epoch: 370
# num_epoch: 371
# num_epoch: 372
# num_epoch: 373
# num_epoch: 374
# num_epoch: 375
# num_epoch: 376
# num_epoch: 377
# num_epoch: 378
# num_epoch: 379
# num_epoch: 380
# num_epoch: 381
# num_epoch: 382
# num_epoch: 383
# num_epoch: 384
# num_epoch: 385
# num_epoch: 386
# num_epoch: 387
# num_epoch: 388
# num_epoch: 389
# num_epoch: 390
# num_epoch: 391
# num_epoch: 392
# num_epoch: 393
# num_epoch: 394
# num_epoch: 395
# num_epoch: 396
# num_epoch: 397
# num_epoch: 398
# num_epoch: 399
# num_epoch: 400
# num_epoch: 401
# num_epoch: 402
# num_epoch: 403
# num_epoch: 404
# num_epoch: 405
# num_epoch: 406
# num_epoch: 407
# num_epoch: 408
# num_epoch: 409
# num_epoch: 410
# num_epoch: 411
# num_epoch: 412
# num_epoch: 413
# num_epoch: 414
# num_epoch: 415
# num_epoch: 416
# num_epoch: 417
# num_epoch: 418
# num_epoch: 419
# num_epoch: 420
# num_epoch: 421
# num_epoch: 422
# num_epoch: 423
# num_epoch: 424
# num_epoch: 425
# num_epoch: 426
# num_epoch: 427
# num_epoch: 428
# num_epoch: 429
# num_epoch: 430
# num_epoch: 431
# num_epoch: 432
# num_epoch: 433
# num_epoch: 434
# num_epoch: 435
# num_epoch: 436
# num_epoch: 437
# num_epoch: 438
# num_epoch: 439
# num_epoch: 440
# num_epoch: 441
# num_epoch: 442
# num_epoch: 443
# num_epoch: 444
# num_epoch: 445
# num_epoch: 446
# num_epoch: 447
# num_epoch: 448
# num_epoch: 449
# num_epoch: 450
# num_epoch: 451
# num_epoch: 452
# num_epoch: 453
# num_epoch: 454
# num_epoch: 455
# num_epoch: 456
# num_epoch: 457
# num_epoch: 458
# num_epoch: 459
# num_epoch: 460
# num_epoch: 461
# num_epoch: 462
# num_epoch: 463
# num_epoch: 464
# num_epoch: 465
# num_epoch: 466
# num_epoch: 467
# num_epoch: 468
# num_epoch: 469
# num_epoch: 470
# num_epoch: 471
# num_epoch: 472
# num_epoch: 473
# num_epoch: 474
# num_epoch: 475
# num_epoch: 476
# num_epoch: 477
# num_epoch: 478
# num_epoch: 479
# num_epoch: 480
# num_epoch: 481
# num_epoch: 482
# num_epoch: 483
# num_epoch: 484
# num_epoch: 485
# num_epoch: 486
# num_epoch: 487
# num_epoch: 488
# num_epoch: 489
# num_epoch: 490
# num_epoch: 491
# num_epoch: 492
# num_epoch: 493
# num_epoch: 494
# num_epoch: 495
# num_epoch: 496
# num_epoch: 497
# num_epoch: 498
# num_epoch: 499
# theta parameters: [[3.00363848]
#  [0.99905013]
#  [1.99920008]]
# rate: 0.001  stopping condition: 1e-11
# Number of epochs: 499

# %%
print(theta)
# Out:
# [[3.00363848]
#  [0.99905013]
#  [1.99920008]]

# %%
tm = len(ty)

tx1 = np.array(tx1).astype(float)
# tx1 = (tx1 - np.mean(tx1)) / (np.std(tx1))

tx2 = np.array(tx2).astype(float)
# tx2 = (tx2 - np.mean(tx2)) / (np.std(tx2))
tx0 = np.full(tm, 1)
# print(x0)

ty=np.array(ty).astype(float)

# %%
tX=np.column_stack((tx0,tx1,tx2)).T
tY=ty.reshape(10000,1).T

print(tX.shape, tY.shape)
# Out:
# (3, 10000) (1, 10000)

# %%
theta_orig = np.array([3,1,2]).reshape(3,1).astype(float)
print(theta_orig,theta_orig.shape)
# Out:
# [[3.]
#  [1.]
#  [2.]] (3, 1)

# %%
cost_lern_para = calc_cost_batch(tX,tY,theta)
cost_orig_para = calc_cost_batch(tX,tY,theta_orig)
print("rate:",rate)
print("stopping condition:",stop)
print("cost with learnt parameters:",cost_lern_para)
print("cost with original parameters:",cost_orig_para)
# Out:
# rate: 0.001
# stopping condition: 1e-11
# cost with learnt parameters: 0.9831762998827508
# cost with original parameters: 0.9829469214999997

# %%
# print(calc_cost(tX,tY,theta,0,tm))

# %%
print(array_theta.shape)
print(np.max(array_theta[:,1]))
# num_rows_theta_arr=array_theta.shape[0]//3
# t=np.resize(array_theta,(num_rows_theta_arr,3))
print(array_theta)
# print(t.shape)
t = array_theta
fig=plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlabel('theta(0)')
ax.set_ylabel('theta(1)')
ax.set_zlabel('theta(2)')
ax.set_xlim(0,np.max(array_theta[:,0]))
ax.set_ylim(0,np.max(array_theta[:,1]))
ax.set_zlim(0,np.max(array_theta[:,2]))

for i in range(0, t.shape[0], 20):
    ax.plot3D(t[0:i,0],t[0:i,1],t[0:i,2],'gray')
    plt.pause(0.02)
    
# print(t[:,0].shape)

plt.show()
# Out:
# (49901, 3)
# 1.4603196291521232
# [[0.         0.         0.        ]
#  [0.00392617 0.01583381 0.00383552]
#  [0.00784388 0.03173165 0.00783587]
#  ...
#  [3.00364459 0.99906004 1.99911001]
#  [3.00365757 0.99911511 1.99910231]
#  [3.00363848 0.99905013 1.99920008]]
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-18-cb73473f06d3> in <module>
#      17 for i in range(0, t.shape[0], 20):
#      18     ax.plot3D(t[0:i,0],t[0:i,1],t[0:i,2],'gray')
# ---> 19     plt.pause(0.02)
#      20
#      21 # print(t[:,0].shape)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in pause(interval)
#     308             canvas.draw_idle()
#     309         show(block=False)
# --> 310         canvas.start_event_loop(interval)
#     311     else:
#     312         time.sleep(interval)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2257         self._looping = True
#    2258         while self._looping and counter * timestep < timeout:
# -> 2259             self.flush_events()
#    2260             time.sleep(timestep)
#    2261             counter += 1
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/_backend_tk.py in flush_events(self)
#     471     def flush_events(self):
#     472         # docstring inherited
# --> 473         self._master.update()
#     474
#     475
#
# ~/anaconda3/lib/python3.7/tkinter/__init__.py in update(self)
#    1175     def update(self):
#    1176         """Enter event loop until all pending events have been processed by Tcl."""
# -> 1177         self.tk.call('update')
#    1178     def update_idletasks(self):
#    1179         """Enter event loop until all idle callbacks have been called. This
#
# TclError: can't invoke "update" command: application has been destroyed
